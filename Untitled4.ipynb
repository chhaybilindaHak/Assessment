# %% [markdown]
# <a href="https://colab.research.google.com/github/chhaybilindaHak/Assessment/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/pycaret/pycaret.git@master
# Out:
# ...
#   Cloning https://github.com/pycaret/pycaret.git (to revision master) to /tmp/pip-req-build-bq0onrg4
#   Running command git clone --filter=blob:none --quiet https://github.com/pycaret/pycaret.git /tmp/pip-req-build-bq0onrg4
#   Resolved https://github.com/pycaret/pycaret.git to commit 58ec3c282d58e94727f9d5b77b49f241e9103ab3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
#numpy and pandas will be used for data manipulationh
import numpy as np
import pandas as pd
#matplotib will be used for visually representing our data
import matplotlib.pyplot as plt
#yfinance will be used for importing historical oil prices
import yfinance as yfin

# %%
#setting our ticker
ticker = 'AMZN'
ticker = yfin.Ticker(ticker)

#importing our data
data = ticker.history(period='5y')

# %%
data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-11-25 00:00:00-05:00  157.093506  159.899994  157.013000  159.253494
# 2020-11-27 00:00:00-05:00  160.563004  160.809494  159.502502  159.766998
# 2020-11-30 00:00:00-05:00  160.423996  161.419495  156.277496  158.401993
# 2020-12-01 00:00:00-05:00  159.425003  162.447495  157.858994  161.003998
# 2020-12-02 00:00:00-05:00  161.082504  161.600006  158.662994  160.176498
# ...                               ...         ...         ...         ...
# 2025-11-19 00:00:00-05:00  223.740005  223.740005  218.520004  222.690002
# 2025-11-20 00:00:00-05:00  227.050003  227.410004  216.740005  217.139999
# 2025-11-21 00:00:00-05:00  216.350006  222.210007  215.179993  220.690002
# 2025-11-24 00:00:00-05:00  222.559998  227.330002  222.270004  226.279999
# 2025-11-25 00:00:00-05:00  226.380005  227.899994  223.800003  227.000000
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
#setting the text on the y-axis
plt.ylabel('Amazon')

#setting the size of our graph
data['Close'].plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date', ylabel='Amazon'>

# %%
#calculate simple moving averagee (5MA)
data['SMA_20'] = data['Close'].rolling(window=20).mean()
data['SMA_50'] = data['Close'].rolling(window=50).mean()

#calculate exponential moving averages (EMA)
data['EMA_20'] = data['Close'].ewm(span=20, adjust=False).mean()

#calculate relative strength indes (RSI)
delta = data['Close'].diff(1)
gain = delta.where(delta > 0, 0)
loss = -delta.where(delta < 0, 0)
avg_gain = gain.rolling(window=14).mean()
avg_loss = loss.rolling(window=14).mean()
rs = avg_gain / avg_loss
data['RSi'] = 100 - (100 / (1 + rs))

data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-11-25 00:00:00-05:00  157.093506  159.899994  157.013000  159.253494
# 2020-11-27 00:00:00-05:00  160.563004  160.809494  159.502502  159.766998
# 2020-11-30 00:00:00-05:00  160.423996  161.419495  156.277496  158.401993
# 2020-12-01 00:00:00-05:00  159.425003  162.447495  157.858994  161.003998
# 2020-12-02 00:00:00-05:00  161.082504  161.600006  158.662994  160.176498
# ...                               ...         ...         ...         ...
# 2025-11-19 00:00:00-05:00  223.740005  223.740005  218.520004  222.690002
# 2025-11-20 00:00:00-05:00  227.050003  227.410004  216.740005  217.139999
# 2025-11-21 00:00:00-05:00  216.350006  222.210007  215.179993  220.690002
# 2025-11-24 00:00:00-05:00  222.559998  227.330002  222.270004  226.279999
# 2025-11-25 00:00:00-05:00  226.380005  227.899994  223.800003  227.000000
#
# ...

# %%
# Dropping the NaN values
data = data.dropna()

# %%
data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-02-08 00:00:00-05:00  167.925003  168.250000  165.199997  166.147003
# 2021-02-09 00:00:00-05:00  165.624496  166.899994  164.891998  165.250000
# 2021-02-10 00:00:00-05:00  165.699997  165.897507  162.699997  164.328995
# 2021-02-11 00:00:00-05:00  164.600006  164.600006  162.403000  163.106506
# 2021-02-12 00:00:00-05:00  162.500000  164.012497  161.665497  163.885498
# ...                               ...         ...         ...         ...
# 2025-11-19 00:00:00-05:00  223.740005  223.740005  218.520004  222.690002
# 2025-11-20 00:00:00-05:00  227.050003  227.410004  216.740005  217.139999
# 2025-11-21 00:00:00-05:00  216.350006  222.210007  215.179993  220.690002
# 2025-11-24 00:00:00-05:00  222.559998  227.330002  222.270004  226.279999
# 2025-11-25 00:00:00-05:00  226.380005  227.899994  223.800003  227.000000
#
# ...

# %%
# Initialising X and assigning the two feature variables
X = data[['EMA_20','SMA_50']]

# Getting the head of the data
X.head()
# Out:
#                                EMA_20     SMA_50
# Date
# 2021-02-08 00:00:00-05:00  163.689976  160.74137
# 2021-02-09 00:00:00-05:00  163.838550  160.86130
# 2021-02-10 00:00:00-05:00  163.885259  160.95254
# 2021-02-11 00:00:00-05:00  163.811092  161.04663
# 2021-02-12 00:00:00-05:00  163.818178  161.10426

# %%
# Setting-up the dependent variable
y = data['Close']

# Getting the head of the data
y.head()
# Out:
# Date
# 2021-02-08 00:00:00-05:00    166.147003
# 2021-02-09 00:00:00-05:00    165.250000
# 2021-02-10 00:00:00-05:00    164.328995
# 2021-02-11 00:00:00-05:00    163.106506
# 2021-02-12 00:00:00-05:00    163.885498
# Name: Close, dtype: float64

# %%
# Setting the training set to 80% of the data
training = 0.7
t = int(training*len(data))

# Training dataset
X_train = X[:t]
y_train = y[:t]

# Testing dataset
X_test = X[t:]
y_test = y[t:]

# %%
X[:t]
# Out:
#                                EMA_20      SMA_50
# Date
# 2021-02-08 00:00:00-05:00  163.689976  160.741370
# 2021-02-09 00:00:00-05:00  163.838550  160.861300
# 2021-02-10 00:00:00-05:00  163.885259  160.952540
# 2021-02-11 00:00:00-05:00  163.811092  161.046630
# 2021-02-12 00:00:00-05:00  163.818178  161.104260
# ...                               ...         ...
# 2024-06-10 00:00:00-04:00  182.609401  182.660201
# 2024-06-11 00:00:00-04:00  183.049458  182.785400
# 2024-06-12 00:00:00-04:00  183.415224  182.909400
# 2024-06-13 00:00:00-04:00  183.454727  182.937800
# 2024-06-14 00:00:00-04:00  183.474277  183.011000
#
# [844 rows x 2 columns]

# %%
from pycaret.regression import *
s = setup(
    data=data[['SMA_20','SMA_50','Close']],
    target='Close',
    session_id=123,
    numeric_features=['SMA_20', 'SMA_50'],
    fold_strategy='timeseries', # Ensures temporal integrity
    data_split_shuffle=False,     # Prevents random shuffling
    n_jobs=-1
)
# Out:
# <style type="text/css">
# #T_fb51c_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fb51c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb51c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fb51c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb51c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb51c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fb51c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_fb51c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fb51c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fb51c_row1_col1" class="data row1 col1" >Close</td>
#     </tr>
#     <tr>
#       <th id="T_fb51c_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_8ae18_row10_col0, #T_8ae18_row10_col1, #T_8ae18_row10_col2, #T_8ae18_row10_col3, #T_8ae18_row10_col4, #T_8ae18_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_8ae18" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ae18_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8ae18_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8ae18_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8ae18_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8ae18_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_8ae18_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tuned_rf = tune_model(rf)
# Out:
# <style type="text/css">
# #T_b7a5f_row10_col0, #T_b7a5f_row10_col1, #T_b7a5f_row10_col2, #T_b7a5f_row10_col3, #T_b7a5f_row10_col4, #T_b7a5f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b7a5f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7a5f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b7a5f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b7a5f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b7a5f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b7a5f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b7a5f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
print(tuned_rf)
# Out:
# RandomForestRegressor(max_depth=6, max_features='log2',
#                       min_impurity_decrease=0.0002, min_samples_leaf=2,
#                       n_estimators=290, n_jobs=-1, random_state=123)

# %%
plot_model(tuned_rf)

# %%
plot_model(tuned_rf, plot = 'error')

# %%
plot_model(tuned_rf, plot = 'feature')

# %%
evaluate_model(tuned_rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(tuned_rf)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ff9e3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff9e3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ff9e3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ff9e3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ff9e3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ff9e3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ff9e3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ff9e3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff9e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff9e3_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_ff9e3_row0_col1" class="data row0 col1" >27.5332</td>
# ...

# %%
final_rf = finalize_model(tuned_rf)

# %%
print(final_rf)
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['SMA_20', 'SMA_50'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('actual_estimator',
#                  RandomForestRegressor(max_depth=6, max_features='log2',
#                                        min_impurity_decrease=0.0002,
#                                        min_samples_leaf=2, n_estimators=290,
#                                        n_jobs=-1, random_state=123))])

# %%
predict_model(final_rf)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2c528" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c528_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2c528_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2c528_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2c528_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2c528_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2c528_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2c528_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c528_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c528_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_2c528_row0_col1" class="data row0 col1" >5.3255</td>
# ...
